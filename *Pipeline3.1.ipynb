# %% [markdown]
# # __Pipeline 3, Pt 1__
# ## _IQR --> Normalization --> Z Score_

# %% [markdown]
# ## Importing Data:

# %%
# import required package for data handling
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt
from pandas import DataFrame
# %matplotlib inline

# import required packages for splitting data
from sklearn import model_selection
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# import required packages for evaluating models
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support

# import `logistic regression` model
from sklearn.linear_model import LogisticRegression

from scipy.stats import boxcox
from scipy import stats

# %%
compdata_original = pd.read_csv('comp1data.csv', header=0, na_values = '-')
compdata_original.head()
# Out:
#      I1                                  I2    I3  P(IPO)  P(H)  P(L)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674    10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834     8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834     7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834    11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492    21.0  21.0  19.0
#
#      P(1Day)     C1   C2    C3  ...          C6       C7     T1       T2  \
# 0  11.870000  122.0  1.0  3.43  ...  10600000.0   51.345  470.0  12719.0
# 1   7.250000  259.0  0.0 -1.62  ...   2400000.0   25.936  791.0  21792.0
# 2   6.700000   90.0  1.0 -1.24  ...   5000000.0    7.378  201.0   5262.0
# 3  12.390000  209.0  1.0 -0.91  ...   4500000.0    8.526  328.0   8259.0
# 4  56.599998   80.0  1.0  0.07  ...   8250000.0  632.298  572.0  14830.0
#
#         T3     T4      T5    S1     S2     S3
# 0  11560.0  301.0   690.0  62.0  117.0  139.0
# 1  19585.0  510.0  1120.0  71.0  242.0  237.0
# 2   4785.0  128.0   325.0  61.0   33.0   60.0
# 3   7574.0  177.0   509.0  80.0   59.0  110.0
# 4  13176.0  336.0   720.0  67.0  149.0  167.0
#
# [5 rows x 22 columns]

# %% [markdown]
# # Descriptive Statistics

# %%
compdata_original.shape
# 682 rows and 22 columns
# Out:
# (682, 22)

# %%
compdata_original.describe()
# Out:
#            P(IPO)        P(H)        P(L)      P(1Day)           C1  \
# count  677.000000  672.000000  672.000000   660.000000   660.000000
# mean    13.837666   15.481190   13.515045    25.934766   149.728788
# std      6.053731    6.653429    5.835646    73.234948   152.817467
# min      3.000000    0.000000    3.000000     0.000000    10.000000
# 25%     10.000000   12.500000   11.000000    11.000000    85.000000
# 50%     13.500000   15.000000   13.000000    14.845000   107.000000
# 75%     17.000000   17.000000   15.000000    20.485000   155.250000
# max     85.000000  135.000000  108.000000  1159.200562  2087.000000
#
#                C2           C3          C4            C5            C6  \
# count  660.000000   646.000000  660.000000  6.760000e+02  6.760000e+02
# mean     0.859091     1.788904    0.007282  4.935776e+07  1.241519e+07
# std      0.348192   162.666532    0.033318  1.043764e+08  2.512855e+07
# min      0.000000  -786.239000   -0.162352  3.693227e+06  5.250000e+05
# 25%      1.000000    -0.852500   -0.013927  1.871417e+07  5.000000e+06
# 50%      1.000000     0.010000    0.009125  2.740018e+07  7.398704e+06
# 75%      1.000000     0.470000    0.031571  4.980786e+07  1.200000e+07
# max      1.000000  3864.500000    0.092896  2.138085e+09  4.212336e+08
#
#                  C7           T1            T2            T3           T4  \
# count    610.000000   681.000000    681.000000    681.000000   681.000000
# mean     500.459962   465.634361  12758.606461  11395.844347   294.353891
# std     1648.337634   175.741647   5449.644597   4839.670179   121.532637
# min        0.074000   132.000000      0.000000      0.000000     0.000000
# 25%       37.245750   351.000000   9195.000000   8162.000000   213.000000
# 50%      103.833000   444.000000  12045.000000  10785.000000   279.000000
# 75%      331.138000   551.000000  15241.000000  13760.000000   354.000000
# max    30683.000000  1750.000000  49056.000000  43952.000000  1058.000000
#
#                  T5          S1          S2          S3
# count    681.000000  681.000000  681.000000  681.000000
# mean     679.220264   68.421439  120.104258  144.759178
# std      472.914323   39.096525   84.828959   69.276285
# min       -1.000000   -1.000000   20.000000   26.000000
# 25%      462.000000   45.000000   73.000000  100.000000
# 50%      624.000000   60.000000  100.000000  134.000000
# 75%      795.000000   85.000000  142.000000  173.000000
# max    10277.000000  309.000000  944.000000  883.000000

# %%
compdata_original.dtypes
# Out:
# I1          object
# I2          object
# I3          object
# P(IPO)     float64
# P(H)       float64
# P(L)       float64
# P(1Day)    float64
# C1         float64
# C2         float64
# C3         float64
# C4         float64
# C5         float64
# C6         float64
# C7         float64
# T1         float64
# T2         float64
# T3         float64
# T4         float64
# T5         float64
# S1         float64
# S2         float64
# S3         float64
# dtype: object

# %%
compdata_original.median()
# Out:
# P(IPO)     1.350000e+01
# P(H)       1.500000e+01
# P(L)       1.300000e+01
# P(1Day)    1.484500e+01
# C1         1.070000e+02
# C2         1.000000e+00
# C3         1.000000e-02
# C4         9.124591e-03
# C5         2.740018e+07
# C6         7.398704e+06
# C7         1.038330e+02
# T1         4.440000e+02
# T2         1.204500e+04
# T3         1.078500e+04
# T4         2.790000e+02
# T5         6.240000e+02
# S1         6.000000e+01
# S2         1.000000e+02
# S3         1.340000e+02
# dtype: float64

# %%
# Create a copy of the data
compdata = compdata_original.copy()

# %% [markdown]
# # Variable Calculations:

# %%
# Impute the rows T2 values!!!! mean
# Cannot do calculations with missing data on the number of words, the ratios will be 0 and create outliers

compdata.loc[compdata['T2'] == 0]
# Out:
#       I1                       I2    I3  P(IPO)  P(H)  P(L)  P(1Day)     C1  \
# 125  CLD  CLOUD PEAK ENERGY INC.   1221    15.0  18.0  16.0    14.84  100.0
# 199  EDG        Edgen Group Inc.   5150    11.0  16.0  14.0     9.50  120.0
#
#       C2    C3  ...          C6        C7     T1   T2       T3     T4      T5  \
# 125  1.0  2.00  ...  30600000.0  1239.711  656.0  0.0  18173.0  486.0  1135.0
# 199  1.0 -0.59  ...  15000000.0   911.612  619.0  0.0  19153.0  474.0  1108.0
#
#         S1     S2     S3
# 125   77.0  229.0  219.0
# 199  104.0  224.0  253.0
#
# [2 rows x 22 columns]

# %%
compdata.loc[125,'T2']=compdata['T2'].mean()

# %%
compdata.loc[199,'T2']=compdata['T2'].mean()

# %%
# check for negatives
# cannot have a negative number of long words (T5)

compdata.loc[compdata['T5'] < 0]
# Out:
#      I1                          I2    I3  P(IPO)  P(H)  P(L)  P(1Day)    C1  \
# 7  ACRX  ACELRX PHARMACEUTICALS INC  2834     5.0  14.0  12.0     4.55  91.0
#
#     C2    C3  ...         C6  C7     T1       T2       T3     T4   T5    S1  \
# 7  0.0 -0.74  ...  8000000.0 NaN  334.0  11226.0  10056.0  276.0 -1.0  55.0
#
#       S2     S3
# 7  120.0  122.0
#
# [1 rows x 22 columns]

# %%
compdata.loc[7,'T5']=compdata['T5'].mean()

# %%
# cannot have a negative number of positive words (S1)
compdata.loc[compdata['S1'] < 0]
# Out:
#        I1            I2    I3  P(IPO)  P(H)  P(L)  P(1Day)     C1   C2    C3  \
# 134  COGT  Cogent, inc.  7373    12.0  12.0  10.0    17.98  133.0  1.0  0.14
#
#      ...          C6      C7     T1       T2      T3     T4     T5   S1    S2  \
# 134  ...  18000000.0  32.179  419.0  10764.0  9856.0  259.0  643.0 -1.0  97.0
#
#         S3
# 134  134.0
#
# [1 rows x 22 columns]

# %%
# Fill the 0, negative, and infinite values with the mean for continuous values
compdata.loc[134,'S1']=compdata['S1'].mean()

# %%
compdata["S1"] = pd.to_numeric(compdata["S1"])

# %%
# Ratios:

    # ** How to find the ratio for T1 and T2... impute them

# Percentage of real words
compdata['T3_'] = (compdata['T3']/compdata['T2'])
# Percentage of long sentences
compdata['T4_'] = (compdata['T4']/compdata['T1'])
# Percentage of long words
compdata['T5_'] = (compdata['T5']/compdata['T2'])
# Percentage of positive words
compdata['S1_'] = (compdata['S1']/compdata['T2'])
# Percentage of negative words
compdata['S2_'] = (compdata['S2']/compdata['T2'])
# Percentage of uncertain words
compdata['S3_'] = (compdata['S3']/compdata['T2'])
compdata.head()

# Target & Control Variable Calculation

compdata['P(mid)'] = ((compdata['P(H)']+compdata['P(L)'])/2)

def p(row):
    if row['P(IPO)'] < row['P(mid)']:
        val = 1
    else:
        val = 0
    return val

def q(row):
    if row['P(1Day)'] > row['P(IPO)']:
        val = 1
    else:
        val = 0
    return val

def r(row):
    if row['C3'] >= 0:
        val = 1
    else:
        val = 0
    return val

def s(row):
    if row['P(IPO)'] > row['P(mid)']:
        val = (row['P(IPO)'] - row['P(mid)'])/row['P(mid)']*100
    else:
        val = 0
    return val

compdata['C3_'] = compdata.apply(r, axis=1)
compdata['C5_'] = compdata['C5']/compdata['C6'] 
compdata['C6_'] = compdata.apply(s, axis=1)
compdata['Y1'] = compdata.apply(p, axis=1)
compdata['Y2'] = compdata.apply(q, axis=1)

# %% [markdown]
# # Missing Data:

# %%
compdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 34 columns):
# I1         682 non-null object
# I2         682 non-null object
# I3         674 non-null object
# P(IPO)     677 non-null float64
# P(H)       672 non-null float64
# P(L)       672 non-null float64
# P(1Day)    660 non-null float64
# C1         660 non-null float64
# C2         660 non-null float64
# C3         646 non-null float64
# C4         660 non-null float64
# C5         676 non-null float64
# C6         676 non-null float64
# C7         610 non-null float64
# T1         681 non-null float64
# T2         681 non-null float64
# T3         681 non-null float64
# T4         681 non-null float64
# T5         681 non-null float64
# S1         681 non-null float64
# S2         681 non-null float64
# S3         681 non-null float64
# T3_        681 non-null float64
# T4_        681 non-null float64
# T5_        681 non-null float64
# S1_        681 non-null float64
# S2_        681 non-null float64
# S3_        681 non-null float64
# P(mid)     672 non-null float64
# C3_        682 non-null int64
# C5_        676 non-null float64
# C6_        682 non-null float64
# Y1         682 non-null int64
# Y2         682 non-null int64
# dtypes: float64(28), int64(3), object(3)
# memory usage: 181.3+ KB

# %%
compdata.isna().sum()
# Out:
# I1          0
# I2          0
# I3          8
# P(IPO)      5
# P(H)       10
# P(L)       10
# P(1Day)    22
# C1         22
# C2         22
# C3         36
# C4         22
# C5          6
# C6          6
# C7         72
# T1          1
# T2          1
# T3          1
# T4          1
# T5          1
# S1          1
# S2          1
# S3          1
# T3_         1
# T4_         1
# T5_         1
# S1_         1
# S2_         1
# S3_         1
# P(mid)     10
# C3_         0
# C5_         6
# C6_         0
# Y1          0
# Y2          0
# dtype: int64

# %%
# what is the percentage of missing data in each column
compdata.isna().mean().round(4) * 100

# Majority of the data is missing from C7
# Out:
# I1          0.00
# I2          0.00
# I3          1.17
# P(IPO)      0.73
# P(H)        1.47
# P(L)        1.47
# P(1Day)     3.23
# C1          3.23
# C2          3.23
# C3          5.28
# C4          3.23
# C5          0.88
# C6          0.88
# C7         10.56
# T1          0.15
# T2          0.15
# T3          0.15
# T4          0.15
# T5          0.15
# S1          0.15
# S2          0.15
# S3          0.15
# T3_         0.15
# T4_         0.15
# T5_         0.15
# S1_         0.15
# S2_         0.15
# S3_         0.15
# P(mid)      1.47
# C3_         0.00
# C5_         0.88
# C6_         0.00
# Y1          0.00
# Y2          0.00
# dtype: float64

# %%
compdata[compdata["I1"]=='DLB']
# Out:
#       I1                         I2                      I3  P(IPO)  P(H)  \
# 174  DLB  Dolby Laboratories, Inc.   6794, 3861, 3663, 7819    18.0  18.0
#
#      P(L)    P(1Day)    C1   C2    C3  ...       T5_       S1_      S2_  \
# 174  16.0  24.299999  90.0  1.0  0.47  ...  0.059655  0.004513  0.00798
#
#           S3_  P(mid)  C3_       C5_       C6_  Y1  Y2
# 174  0.010793    17.0    1  3.540441  5.882353   0   1
#
# [1 rows x 34 columns]

# %%
compdata[compdata["I1"]=='DTSI']
# Out:
#        I1         I2                I3  P(IPO)  P(H)  P(L)  P(1Day)    C1  \
# 187  DTSI  DTS, INC.  3651, 6794, 7819    17.0  16.0  14.0    24.92  76.0
#
#       C2    C3  ...       T5_       S1_       S2_      S3_  P(mid)  C3_  \
# 187  0.0  0.99  ...  0.050882  0.005922  0.011482  0.00846    15.0    1
#
#           C5_        C6_  Y1  Y2
# 187  3.410759  13.333333   0   1
#
# [1 rows x 34 columns]

# %%
compdata[compdata["I1"]=='RLD']
# Out:
#       I1          I2                I3  P(IPO)  P(H)  P(L)  P(1Day)    C1  \
# 499  RLD  RealD Inc.  3663, 3861, 6794    16.0  15.0  13.0    19.51  98.0
#
#       C2    C3  ...       T5_       S1_      S2_       S3_  P(mid)  C3_  \
# 499  1.0 -0.33  ...  0.056527  0.006539  0.00874  0.014273    14.0    0
#
#          C5_        C6_  Y1  Y2
# 499  3.81107  14.285714   0   1
#
# [1 rows x 34 columns]

# %%
compdata[compdata["I1"]=='UPG']
# Out:
#       I1                      I2          I3  P(IPO)  P(H)  P(L)  P(1Day)  \
# 620  UPG  UNIVERSAL POWER GROUP   7389, 5063     7.0   9.0   7.0     7.35
#
#         C1   C2    C3  ...      T5_     S1_       S2_      S3_  P(mid)  C3_  \
# 620  101.0  0.0  0.38  ...  0.04157  0.0042  0.008835  0.00956     8.0    1
#
#           C5_  C6_  Y1  Y2
# 620  1.666667  0.0   1   1
#
# [1 rows x 34 columns]

# %%
compdata.I3.replace(to_replace ="6794, 3861, 3663, 7819", value ="3000", inplace=True)

# %%
compdata.I3.replace(to_replace ="3651, 6794, 7819", value ="9900", inplace=True)

# %%
compdata.I3.replace(to_replace ="3663, 3861, 6794", value ="3000", inplace=True)

# %%
compdata.I3.replace(to_replace ="7389, 5063", value ="9900", inplace=True)

# %%
compdata.I3.replace(to_replace ="541990", value ="7000", inplace=True)

# %%
compdata["I3"] = pd.to_numeric(compdata["I3"])

# %%
compdata.isna().sum()
# Out:
# I1          0
# I2          0
# I3          8
# P(IPO)      5
# P(H)       10
# P(L)       10
# P(1Day)    22
# C1         22
# C2         22
# C3         36
# C4         22
# C5          6
# C6          6
# C7         72
# T1          1
# T2          1
# T3          1
# T4          1
# T5          1
# S1          1
# S2          1
# S3          1
# T3_         1
# T4_         1
# T5_         1
# S1_         1
# S2_         1
# S3_         1
# P(mid)     10
# C3_         0
# C5_         6
# C6_         0
# Y1          0
# Y2          0
# dtype: int64

# %%
# Since C2 is a binary value, we will fill the missing data with the mode

compdata['Imputed_C2'] = compdata['C2'].fillna(compdata['C2'].mode()[0])
compdata.head()
# Out:
#      I1                                  I2      I3  P(IPO)  P(H)  P(L)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674.0    10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834.0     8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834.0     7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834.0    11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492.0    21.0  21.0  19.0
#
#      P(1Day)     C1   C2    C3  ...       S1_       S2_       S3_  P(mid)  \
# 0  11.870000  122.0  1.0  3.43  ...  0.004875  0.009199  0.010929     9.0
# 1   7.250000  259.0  0.0 -1.62  ...  0.003258  0.011105  0.010876     9.0
# 2   6.700000   90.0  1.0 -1.24  ...  0.011593  0.006271  0.011403    13.0
# 3  12.390000  209.0  1.0 -0.91  ...  0.009686  0.007144  0.013319    15.0
# 4  56.599998   80.0  1.0  0.07  ...  0.004518  0.010047  0.011261    20.0
#
#    C3_        C5_        C6_  Y1  Y2  Imputed_C2
# 0    1   3.864345  11.111111   0   1         1.0
# 1    0  12.028832   0.000000   1   0         0.0
# 2    0   3.369134   0.000000   1   0         1.0
# 3    0   3.299697   0.000000   1   1         1.0
# 4    1   3.726269   5.000000   0   1         1.0
#
# [5 rows x 35 columns]

# %%
compdata['Imputed_C7'] = compdata['C7'].fillna(compdata['C7'].mean())

# %%
compdata.isna().sum()
# Out:
# I1             0
# I2             0
# I3             8
# P(IPO)         5
# P(H)          10
# P(L)          10
# P(1Day)       22
# C1            22
# C2            22
# C3            36
# C4            22
# C5             6
# C6             6
# C7            72
# T1             1
# T2             1
# T3             1
# T4             1
# T5             1
# S1             1
# S2             1
# S3             1
# T3_            1
# T4_            1
# T5_            1
# S1_            1
# S2_            1
# S3_            1
# P(mid)        10
# C3_            0
# C5_            6
# C6_            0
# Y1             0
# Y2             0
# Imputed_C2     0
# Imputed_C7     0
# dtype: int64

# %%
# Drop missing P Values from Continues DF

compdata = compdata.dropna(subset=['P(1Day)'], axis=0, how='any')

# %%
compdata.reset_index(drop=True, inplace=True)
# Out:
#        I1                             I2      I3  P(IPO)  P(H)  P(L)  \
# 640   WMG      Warner Music Group Corp.   7929.0    17.0  24.0  22.0
# 641   WNR         Western Refining, Inc.  2911.0    17.0  17.0  15.0
# 642  WOLF       Great Wolf Resorts, Inc.  7011.0    17.0  17.0  15.0
# 643  WSSI          VISUAL SCIENCES, INC.  7372.0     8.5   9.0   8.0
# 644  WSTC                      WEST CORP  7389.0    20.0  25.0  22.0
# 645   WTI              W&T OFFSHORE INC   1311.0    19.0  18.5  16.5
# 646  XCYT  Cyclacel Pharmaceuticals, Inc  2834.0     8.0  15.0  13.0
# 647  XGEN                  XENOGEN CORP   2835.0     7.0  11.0   9.0
# 648  XPRT                     LECG CORP   8742.0    17.0  16.0  14.0
# 649   XRM        XERIUM TECHNOLOGIES INC  2221.0    12.0  16.0  14.0
# 650  XTNT                      XTENT INC  3841.0    16.0  18.0  16.0
# 651  XTXI         ENLINK MIDSTREAM, INC.  1311.0    19.5  18.5  16.5
# 652     Z                     ZILLOW INC  7389.0    20.0  14.0  12.0
# 653   ZBB                   EnSync, Inc.  4911.0     6.0   6.5   5.5
# 654  ZINC        Horsehead Holding Corp   3341.0    18.0  20.0  18.0
# 655   ZIP                     ZIPCAR INC  7514.0    18.0  16.0  14.0
# 656  ZLTQ         Zeltiq Aesthetics Inc   3845.0    13.0  16.0  14.0
# 657  ZSTN     ZST Digital Networks, Inc.  3663.0     8.0   8.5   7.5
# 658  ZUMZ                    Zumiez Inc   5600.0    19.0  17.0  15.0
# 659    ZZ                     SEALY CORP  2510.0    16.0  16.0  14.0
#
#         P(1Day)      C1   C2     C3  ...       S2_       S3_  P(mid)  C3_  \
# 640   16.400000    61.0  1.0  -6.43  ...  0.015820  0.010191    23.0    0
# 641   18.590000   114.0  1.0   3.69  ...  0.007342  0.009553    16.0    1
# 642   21.000000   125.0  1.0  -0.16  ...  0.007286  0.007206    16.0    0
# 643    9.040000   124.0  0.0  -0.86  ...  0.009925  0.011278     8.5    0
# 644   18.860001  1267.0  1.0   8.32  ...  0.010746  0.011594    23.5    1
# 645   18.500000   270.0  1.0   2.82  ...  0.009976  0.012339    17.5    1
# 646  511.700000   158.0  0.0 -12.40  ...  0.008629  0.013140    14.0    0
# 647    7.500000   105.0  1.0 -33.89  ...  0.014114  0.012745    10.0    0
# 648   21.030001    81.0  1.0  -1.41  ...  0.005872  0.011744    15.0    0
# 649  239.999940   389.0  1.0 -24.75  ...  0.013454  0.013076    15.0    0
# 650   16.480000   178.0  1.0  -1.60  ...  0.010242  0.016967    17.0    0
# 651    8.466666    75.0  0.0    NaN  ...  0.010117  0.012665    17.5    0
# 652   35.770000    93.0  1.0  -0.53  ...  0.006528  0.012830    13.0    0
# 653   29.000000   234.0  0.0  -0.60  ...  0.006467  0.006359     6.0    0
# 654   18.600000   119.0  1.0   2.70  ...  0.008195  0.010927    19.0    1
# 655   28.000000   317.0  1.0  -0.37  ...  0.007935  0.012950    15.0    0
# 656   15.500000    98.0  1.0  -0.41  ...  0.009124  0.012527    15.0    0
# 657    7.520000   112.0  0.0   0.60  ...  0.009044  0.009926     8.0    1
# 658   12.435000    78.0  1.0   0.20  ...  0.005362  0.014110    16.0    1
# 659    8.340122   281.0  1.0   0.76  ...  0.008834  0.013551    15.0    1
#
#           C5_        C6_  Y1  Y2  Imputed_C2   Imputed_C7
# 640  4.553691   0.000000   1   0         1.0  3436.000000
# 641  2.953022   6.250000   0   1         1.0  3406.653000
# 642  2.011593   6.250000   0   1         1.0    47.824000
# 643  3.111096   0.000000   0   1         0.0    16.360000
# 644  3.921146   0.000000   1   0         1.0   820.665000
# 645  5.212790   8.571429   0   0         1.0   508.715000
# 646  3.517192   0.000000   1   1         0.0     0.170000
# 647  3.494590   0.000000   1   1         1.0    20.063000
# 648  2.740591  13.333333   0   1         1.0   133.704000
# 649  3.269683   0.000000   1   1         1.0   586.794000
# 650  4.850278   0.000000   1   1         1.0   500.459962
# 651  5.088182  11.428571   0   0         0.0   500.459962
# 652  2.752257  53.846154   0   1         1.0    30.467000
# 653  2.577852   0.000000   0   1         0.0   540.399000
# 654  6.994796   0.000000   1   1         1.0   496.413000
# 655  3.963872  20.000000   0   1         1.0   186.101000
# 656  4.679726   0.000000   1   1         1.0    25.461000
# 657  3.673544   0.000000   0   0         0.0    55.431000
# 658  4.217684  18.750000   0   0         1.0   117.857000
# 659  3.240507   6.666667   0   0         1.0  1469.574000
#
# [20 rows x 36 columns]

# %%
# Create DF with only continuous features

# Drop the imputed variable colmuns
# Drop the P values
# Drop Y1 Y2 **make seperate df
    # Drop T1 and T2?

compdata_cont = compdata.drop(['P(IPO)','P(H)','P(L)','P(1Day)','P(mid)','I1','I2','I3','T3','T1','T2','T4','T5','C3_','S1','S2','S3','C2','C3','C5','C6','C7','Imputed_C2','Y1','Y2'], axis=1)
compdata_cont.head()
# Out:
#       C1        C4       T3_       T4_       T5_       S1_       S2_  \
# 0  122.0  0.029074  0.908876  0.640426  0.054250  0.004875  0.009199
# 1  259.0 -0.013352  0.898724  0.644753  0.051395  0.003258  0.011105
# 2   90.0  0.020715  0.909350  0.636816  0.061764  0.011593  0.006271
# 3  209.0  0.020023  0.917060  0.539634  0.061630  0.009686  0.007144
# 4   80.0 -0.034895  0.888469  0.587413  0.048550  0.004518  0.010047
#
#         S3_        C5_        C6_  Imputed_C7
# 0  0.010929   3.864345  11.111111      51.345
# 1  0.010876  12.028832   0.000000      25.936
# 2  0.011403   3.369134   0.000000       7.378
# 3  0.013319   3.299697   0.000000       8.526
# 4  0.011261   3.726269   5.000000     632.298

# %%
compdata_cont.isna().sum()
# Out:
# C1            0
# C4            0
# T3_           0
# T4_           0
# T5_           0
# S1_           0
# S2_           0
# S3_           0
# C5_           0
# C6_           0
# Imputed_C7    0
# dtype: int64

# %%
compdata_cont.shape
# Out:
# (660, 11)

# %%
# Create DF with only categorical features
# drop y1 y2 c2 i3
compdata_cat = compdata.drop(['P(IPO)','P(H)','I1','I2','P(L)','P(1Day)','P(mid)','I3','C2','C1','C3','C4','C5','C6','C7','T1','T2','T3','T4','T5','S1','S2','S3','T3_','T4_','T5_','S1_','S2_','S3_','C5_','C6_','Y1','Y2','Imputed_C7'], axis=1)
compdata_cat.head()
# Out:
#    C3_  Imputed_C2
# 0    1         1.0
# 1    0         0.0
# 2    0         1.0
# 3    0         1.0
# 4    1         1.0

# %%
compdata_cat.shape
# Out:
# (660, 2)

# %%
targetvals = compdata.drop(['P(IPO)','P(H)','P(L)','P(1Day)','P(mid)','I3','C2','C1','C3','C4','C5','C6','C7','T1','T2','T3','T4','T5','S1','S2','S3','T3_','T4_','T5_','S1_','S2_','S3_','C5_','C6_','I1','I2','C3_','Imputed_C2','Imputed_C7'], axis=1)
targetvals.head()
# Out:
#    Y1  Y2
# 0   0   1
# 1   1   0
# 2   1   0
# 3   1   1
# 4   0   1

# %%
compdata_cont.describe()
# Out:
#                 C1          C4         T3_         T4_         T5_  \
# count   660.000000  660.000000  660.000000  660.000000  660.000000
# mean    149.728788    0.007282    0.891532    0.626720    0.052264
# std     152.817467    0.033318    0.071892    0.077686    0.007075
# min      10.000000   -0.162352    0.000000    0.000000    0.031595
# 25%      85.000000   -0.013927    0.883417    0.580329    0.047562
# 50%     107.000000    0.009125    0.897294    0.628861    0.051943
# 75%     155.250000    0.031571    0.909693    0.674461    0.056544
# max    2087.000000    0.092896    1.498982    0.826347    0.088960
#
#               S1_         S2_         S3_         C5_         C6_  \
# count  660.000000  660.000000  660.000000  660.000000  660.000000
# mean     0.005318    0.009056    0.011516    4.417255    5.404645
# std      0.001743    0.002991    0.002843    5.133537   10.877569
# min      0.001602    0.002152    0.005326    0.283223    0.000000
# 25%      0.004134    0.006966    0.009579    2.850622    0.000000
# 50%      0.005041    0.008577    0.011301    3.731035    0.000000
# 75%      0.006256    0.010521    0.012848    4.857904    7.692308
# max      0.012839    0.024605    0.029397   99.787255  100.000000
#
#          Imputed_C7
# count    660.000000
# mean     506.358456
# std     1583.637898
# min        0.074000
# 25%       41.458000
# 50%      133.102000
# 75%      500.459962
# max    30683.000000

# %% [markdown]
# #### Run evaluation code now.. go back and check the results to see if it improved or not
#
# ##### after impute, after min max, after normalization

# %% [markdown]
# # Pipeline 3.1:

# %% [markdown]
# ## Interquartile Ratio:

# %%
compdata.shape
# Out:
# (660, 36)

# %%
# Determine if there are any outliers in the data that will alter the results
# Use box plots for all the variables to visualize the outliers 

# only continuous df!!!

# %%
compdata_cont.boxplot(vert=False, figsize=(15,10))
plt.title('IPO Characteristics Box Plot')
plt.show()

# %%
compdata_cont.boxplot(column=['C1','C4','C5_','C6_','Imputed_C7'],vert=False, figsize=(15,4))
plt.title('IPO Characteristics Box Plot')
plt.show()

# %%
compdata_cont.boxplot(column=['C1'],vert=False, figsize=(15,1))
plt.title('Days Box Plot')
plt.show()

# %%
compdata_cont.boxplot(column='C4',vert=False, figsize=(15,1))
plt.title('Prior Nasdaq 15-Day Returns Box Plot')
plt.show()

# %%
compdata_cont.boxplot(column=['C5_','C6_'],vert=False, figsize=(15,2))
plt.title('Outstanding Shares & Offering Shares Box Plot')
plt.show()

# %%
# in millions of dollars

compdata_cont.boxplot(column='Imputed_C7',vert=False, figsize=(15,1))
plt.title('Sales Box Plot')
plt.show()

# %%
compdata_cont.boxplot(column=['T3_','T4_','T5_'],vert=False, figsize=(15,4))
plt.title('Textual Characteristics of IPO Box Plot')
plt.show()

# %%
compdata_cont.boxplot(column=['S1_','S2_','S3_'],vert=False, figsize=(15,3))
plt.title('Sentiment Characteristics of IPO Box Plot')
plt.show()

# %% [markdown]
# It is obvious that there are outliers in the dataset that will offset the results.
# To remove this data we will use the interquartile range to determine the upper and lower bound limits and any data outside the limit will be converted to either the lower or upper bound number.

# %%
for col in compdata_cont.columns:
    u_bound = compdata_cont[col].quantile(0.75) + (1.5*(compdata_cont[col].quantile(0.75)-compdata_cont[col].quantile(0.25)))
    compdata_cont[col][compdata_cont[col] > u_bound] = u_bound

# %%
for col in compdata_cont.columns:
    l_bound = compdata_cont[col].quantile(0.25) - (1.5*(compdata_cont[col].quantile(0.75)-compdata_cont[col].quantile(0.25)))
    compdata_cont[col][compdata_cont[col] < l_bound] = l_bound

# %%
compdata_cont.boxplot(vert=False, figsize=(15,10))
plt.title('IPO Characteristics Box Plot')
plt.show()

# %%
compdata_cont.boxplot(column=['C1','C4','C5_','C6_','Imputed_C7'],vert=False, figsize=(15,4))
plt.title('IPO Characteristics Box Plot')
plt.show()

# %%
compdata_cont.boxplot(column=['T3_','T4_','T5_'],vert=False, figsize=(15,4))
plt.title('Textual Characteristics of IPO Box Plot')
plt.show()

# %%
compdata_cont.boxplot(column=['S1_','S2_','S3_'],vert=False, figsize=(15,3))
plt.title('Sentiment Characteristics of IPO Box Plot')
plt.show()

# %%
compdata_cont.describe()
# Out:
#                C1          C4         T3_         T4_         T5_         S1_  \
# count  660.000000  660.000000  660.000000  660.000000  660.000000  660.000000
# mean   126.911932    0.007433    0.894481    0.628160    0.052204    0.005288
# std     64.094744    0.032757    0.021956    0.069922    0.006798    0.001651
# min     10.000000   -0.082174    0.844003    0.439132    0.034087    0.001602
# 25%     85.000000   -0.013927    0.883417    0.580329    0.047562    0.004134
# 50%    107.000000    0.009125    0.897294    0.628861    0.051943    0.005041
# 75%    155.250000    0.031571    0.909693    0.674461    0.056544    0.006256
# max    260.625000    0.092896    0.949107    0.815658    0.070019    0.009440
#
#               S2_         S3_         C5_         C6_   Imputed_C7
# count  660.000000  660.000000  660.000000  660.000000   660.000000
# mean     0.008977    0.011425    4.009806    4.363858   300.316300
# std      0.002749    0.002522    1.647987    6.431440   359.192960
# min      0.002152    0.005326    0.283223    0.000000     0.074000
# 25%      0.006966    0.009579    2.850622    0.000000    41.458000
# 50%      0.008577    0.011301    3.731035    0.000000   133.102000
# 75%      0.010521    0.012848    4.857904    7.692308   500.459962
# max      0.015854    0.017752    7.868826   19.230769  1188.962906

# %% [markdown]
# ## Skewness

# %%
f, axes = plt.subplots(3, 4, figsize=(15,10), sharex=False)
sns.distplot( compdata_cont["C1"] , ax=axes[0, 0])
sns.distplot( compdata_cont["C4"] , ax=axes[0, 1])
sns.distplot( compdata_cont["T3_"] , ax=axes[0, 2])
sns.distplot( compdata_cont["T4_"] , ax=axes[0, 3])
sns.distplot( compdata_cont["T5_"] , ax=axes[1, 0])
sns.distplot( compdata_cont["S1_"] , ax=axes[1, 1])
sns.distplot( compdata_cont["S2_"] , ax=axes[1, 2])
sns.distplot( compdata_cont["S3_"] , ax=axes[1, 3])
sns.distplot( compdata_cont["C5_"] , ax=axes[2, 0])
sns.distplot( compdata_cont["C6_"] , ax=axes[2, 1])
sns.distplot( compdata_cont["Imputed_C7"] , ax=axes[2, 2])
plt.show()

# %%
compdata_cont.skew()

# check if its left or right skewed
# close to 0 is normal (T4_).. [-.5 - .5]
# Positive Skew: --> log
# Negative Skew: --> exponential
# Out:
# C1            0.836620
# C4           -0.314465
# T3_          -0.545971
# T4_          -0.073967
# T5_           0.110769
# S1_           0.608468
# S2_           0.694781
# S3_           0.476608
# C5_           0.724354
# C6_           1.201653
# Imputed_C7    1.437034
# dtype: float64

# %%
# df = pd.compdata_cont(['C1','C4','T3_','T4_','T5_','S1_','S2_','S3_','C5_','C6_','Imputed_C7'])

# %%
compdata_cont['C1_skew'] =  stats.yeojohnson(compdata_cont['C1'])[0]

# %%
compdata_cont['C4_skew'] =  stats.yeojohnson(compdata_cont['C4'])[0]

# %%
compdata_cont['T3_skew'] =  stats.yeojohnson(compdata_cont['T3_'])[0]

# %%
compdata_cont['T4_skew']= stats.yeojohnson(compdata_cont['T4_'])[0]

# %%
compdata_cont['T5_skew']= stats.yeojohnson(compdata_cont['T5_'])[0]

# %%
compdata_cont['S1_skew']= stats.yeojohnson(compdata_cont['S1_'])[0]

# %%
compdata_cont['S2_skew']= stats.yeojohnson(compdata_cont['S2_'])[0]

# %%
compdata_cont['S3_skew']= stats.yeojohnson(compdata_cont['S3_'])[0]

# %%
compdata_cont['C5_skew'] =  stats.yeojohnson(compdata_cont['C5_'])[0]

# %%
compdata_cont['C6_skew'] =  stats.yeojohnson(compdata_cont['C6_'])[0]

# %%
compdata_cont['Imputed_C7_skew']= stats.yeojohnson(compdata_cont['Imputed_C7'])[0]

# 0 outputs 1 column and does not add the lambda

# %%
compdata_cont.skew()
# Out:
# C1                 0.836620
# C4                -0.314465
# T3_               -0.545971
# T4_               -0.073967
# T5_                0.110769
# S1_                0.608468
# S2_                0.694781
# S3_                0.476608
# C5_                0.724354
# C6_                1.201653
# Imputed_C7         1.437034
# C1_skew            0.025613
# C4_skew           -0.014645
# T3_skew           -0.006410
# T4_skew           -0.004147
# T5_skew           -0.000515
# S1_skew            0.028785
# S2_skew            0.040701
# S3_skew            0.012770
# C5_skew            0.004073
# C6_skew            0.518426
# Imputed_C7_skew   -0.080706
# dtype: float64

# %%
compdata_cont['C6_skew'] = compdata_cont['C6_skew'].apply(np.cbrt)
compdata_cont['C6_skew'] = compdata_cont['C6_skew'].apply(np.cbrt)
compdata_cont['C6_skew'] = compdata_cont['C6_skew'].apply(np.cbrt)
compdata_cont['C6_skew'] = compdata_cont['C6_skew'].apply(np.cbrt)
compdata_cont['C6_skew'].skew()
# Out:
# 0.48101448385545925

# %%
compdata_cont.skew()
# Out:
# C1                 0.836620
# C4                -0.314465
# T3_               -0.545971
# T4_               -0.073967
# T5_                0.110769
# S1_                0.608468
# S2_                0.694781
# S3_                0.476608
# C5_                0.724354
# C6_                1.201653
# Imputed_C7         1.437034
# C1_skew            0.025613
# C4_skew           -0.014645
# T3_skew           -0.006410
# T4_skew           -0.004147
# T5_skew           -0.000515
# S1_skew            0.028785
# S2_skew            0.040701
# S3_skew            0.012770
# C5_skew            0.004073
# C6_skew            0.481014
# Imputed_C7_skew   -0.080706
# dtype: float64

# %%
f, axes = plt.subplots(3, 4, figsize=(15,10), sharex=False)
sns.distplot( compdata_cont["C1_skew"] , ax=axes[0, 0])
sns.distplot( compdata_cont["C4_skew"] , ax=axes[0, 1])
sns.distplot( compdata_cont["T3_skew"] , ax=axes[0, 2])
sns.distplot( compdata_cont["T4_skew"] , ax=axes[0, 3])
sns.distplot( compdata_cont["T5_skew"] , ax=axes[1, 0])
sns.distplot( compdata_cont["S1_skew"] , ax=axes[1, 1])
sns.distplot( compdata_cont["S2_skew"] , ax=axes[1, 2])
sns.distplot( compdata_cont["S3_skew"] , ax=axes[1, 3])
sns.distplot( compdata_cont["C5_skew"] , ax=axes[2, 0])
sns.distplot( compdata_cont["C6_skew"] , ax=axes[2, 1])
sns.distplot( compdata_cont["Imputed_C7_skew"] , ax=axes[2, 2])
plt.show()

# %%
compdata_cont_skew = compdata_cont.drop(['C1','C4','T3_','T4_','T5_','S1_','S2_','S3_','C5_','C6_','Imputed_C7'],axis=1)

# %% [markdown]
# # Z Score:

# %%
compdata_cont_skew.plot(figsize=(14,7))
plt.title('Before ZScore')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# create scaler
scaler = StandardScaler()

# fit and transform in one step
compdata_cont_skew = scaler.fit_transform(compdata_cont_skew)
compdata_cont_transform = pd.DataFrame(compdata_cont_skew)

# %%
compdata_cont_transform.columns=['C1_skew','C4_skew','T3_skew','T4_skew','T5_skew','S1_skew','S2_skew','S3_skew','C5_skew','C6_skew','Imputed_C7_skew']

# %%
compdata_cont_transform.describe()
# Out:
#             C1_skew       C4_skew       T3_skew       T4_skew       T5_skew  \
# count  6.600000e+02  6.600000e+02  6.600000e+02  6.600000e+02  6.600000e+02
# mean  -4.710037e-16 -2.287732e-17  9.958364e-17  1.534126e-16  8.955799e-16
# std    1.000758e+00  1.000758e+00  1.000758e+00  1.000758e+00  1.000758e+00
# min   -2.982277e+00 -2.413862e+00 -2.001621e+00 -2.626353e+00 -2.784851e+00
# 25%   -5.800821e-01 -6.941430e-01 -5.910356e-01 -6.919993e-01 -6.744245e-01
# 50%   -1.737376e-01 -8.557685e-03  3.625119e-02 -2.673322e-03 -2.042265e-02
# 75%    5.678089e-01  7.183887e-01  6.656203e-01  6.561838e-01  6.503002e-01
# max    1.801024e+00  3.034115e+00  3.185190e+00  2.763649e+00  2.522977e+00
#
#             S1_skew       S2_skew       S3_skew       C5_skew       C6_skew  \
# count  6.600000e+02  6.600000e+02  6.600000e+02  6.600000e+02  6.600000e+02
# mean   9.635390e-16 -5.625130e-16  9.043271e-16 -5.678959e-16  4.844610e-17
# std    1.000758e+00  1.000758e+00  1.000758e+00  1.000758e+00  1.000758e+00
# min   -2.917302e+00 -3.593944e+00 -2.974704e+00 -3.513421e+00 -7.884290e-01
# 25%   -6.699071e-01 -7.126980e-01 -7.101996e-01 -6.567276e-01 -7.884290e-01
# 50%   -4.148324e-02 -1.887420e-02  3.527544e-02 -4.550610e-02 -7.884290e-01
# 75%    6.843195e-01  6.823410e-01  6.348924e-01  6.167642e-01  1.267539e+00
# max    2.089019e+00  2.036182e+00  2.167861e+00  1.988896e+00  1.270849e+00
#
#        Imputed_C7_skew
# count     6.600000e+02
# mean     -4.696580e-16
# std       1.000758e+00
# min      -2.122226e+00
# 25%      -7.184406e-01
# 50%      -5.295505e-02
# 75%       8.995405e-01
# max       1.657294e+00

# %% [markdown]
# ## Binning:
#
# | Range of SIC Codes | Division |
# | ------------ | ---------- |
# | 0100-0999 | Agriculture, Forestry and Fishing |
# | 1000-1499 | Mining |
# | 1800-1999 | not used |
# | 2000-3999 | Manufacturing |
# | 4000-4999 | Transportation, Communications, Electric, Gas and Sanitary service |
# | 5000-5199 | Wholesale Trade |
# | 5200-5999 | Retail Trade |
# | 6000-6799 | Finance, Insurance and Real Estate |
# | 7000-8999 | Services |
# | 9100-9729 | Public Administration |
# | 9900-9999 | Nonclassifiable |

# %%
def assign_I3_bins(I3):
    if I3 >= 100 and I3 <= 999:                    
        return(1)
    if I3 >= 1000 and I3 <= 1499:       
        return(2)
    if I3 >= 1500 and I3 <= 1799:       
        return(3)
    if I3 >= 1800 and I3 <= 1999:      
        return(4)
    if I3 >= 2000 and I3 <= 3999:                  
        return(5)
    if I3 >= 4000 and I3 <= 4999:                  
        return(6)
    if I3 >= 5000 and I3 <= 5199:                 
        return(7)
    if I3 >= 5200 and I3 <= 5999:                  
        return(8)
    if I3 >= 6000 and I3 <= 6799:                 
        return(9)
    if I3 >= 7000 and I3 <= 8999:                  
        return(10)
    if I3 >= 9100 and I3 <= 9729:                  
        return(11)   
    if I3 >= 9900 and I3 <= 9999:                  
        return(12)   
    
    # Creating a new column I3_bins in the dataframe

compdata_cat['I3_bins'] = compdata['I3'].apply(assign_I3_bins)  

compdata_cat.head()
# Out:
#    C3_  Imputed_C2  I3_bins
# 0    1         1.0        5
# 1    0         0.0        5
# 2    0         1.0        5
# 3    0         1.0        5
# 4    1         1.0        6

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(18,4))

# PLOT - distribution of industry bins
plt.subplot(1,2,1)
plt.text(4,260,"5 and 10 by a large margin!")
ax = sns.countplot(x="I3_bins", data=compdata_cat, palette="viridis")
ax.set(title="Distribution of Industry Bins")

plt.show()

# %% [markdown]
# ## New Bins:
#
# | Range of SIC Codes | Division |
# | ------------ | ---------- |
# | 0100-1999 | Other |
# | 2000-3999 | Manufacturing |
# | 4000-6799 | Other |
# | 7000-8999 | Services |
# | 9100-9999 | Other |

# %%
def assign_I3_bins_new(I3):
    if I3 >= 100 and I3 <= 1999:                          
        return(1)
    if I3 >= 2000 and I3 <= 3999:                  
        return(2)
    if I3 >= 4000 and I3 <= 6799:                  
        return(1)
    if I3 >= 7000 and I3 <= 8999:                  
        return(3)
    if I3 >= 9000 and I3 <= 9999:                  
        return(1)   
    
    # Creating a new column I3_bins in the dataframe

compdata_cat['I3_bins_new'] = compdata['I3'].apply(assign_I3_bins_new)  

compdata_cat.head()
# Out:
#    C3_  Imputed_C2  I3_bins  I3_bins_new
# 0    1         1.0        5            2
# 1    0         0.0        5            2
# 2    0         1.0        5            2
# 3    0         1.0        5            2
# 4    1         1.0        6            1

# %%
compdata_cat = compdata_cat.drop('I3_bins', axis=1)
compdata_cat.head()
# Out:
#    C3_  Imputed_C2  I3_bins_new
# 0    1         1.0            2
# 1    0         0.0            2
# 2    0         1.0            2
# 3    0         1.0            2
# 4    1         1.0            1

# %% [markdown]
# ## Correlation

# %%
#Create Correlation df
corr = compdata_cont_transform.corr()
fig, ax = plt.subplots(figsize=(15, 9))
sns.heatmap(corr, annot=True, fmt=".3f", cmap="Blues")
plt.show()

# %%
# compdata_cont_corr = compdata_cont_corr.join(['compdata_cat','targetvals'])
pipeline3_1 = pd.concat([compdata_cont_transform,compdata_cat,targetvals], axis=1)
pipeline3_1.head()
# Out:
#     C1_skew   C4_skew   T3_skew   T4_skew   T5_skew   S1_skew   S2_skew  \
# 0  0.075166  0.634522  0.622036  0.163401  0.317875 -0.150781  0.220314
# 1  1.784572 -0.677744  0.105400  0.225731 -0.101333 -1.358504  0.867934
# 2 -0.482648  0.359251  0.647280  0.111490  1.391500  2.089019 -1.047739
# 3  1.244371  0.336847  1.073356 -1.260460  1.372745  2.089019 -0.630430
# 4 -0.681012 -1.268502 -0.371534 -0.592161 -0.525495 -0.394125  0.523762
#
#     S3_skew   C5_skew   C6_skew  Imputed_C7_skew  C3_  Imputed_C2  \
# 0 -0.118560  0.038988  1.269109        -0.607280    1         1.0
# 1 -0.140780  1.988896 -0.788429        -0.946172    0         0.0
# 2  0.076708 -0.284815 -0.788429        -1.452379    0         1.0
# 3  0.805082 -0.332517 -0.788429        -1.401754    0         1.0
# 4  0.019050 -0.048561  1.265166         1.092803    1         1.0
#
#    I3_bins_new  Y1  Y2
# 0            2   0   1
# 1            2   1   0
# 2            2   1   0
# 3            2   1   1
# 4            1   0   1

# %%
pipeline3_1.to_csv('../project1-deadlinedemons/pipeline3_1.csv', index=0)

# %%
# check for infinite numbers in df

# log all the values for the continues values *positives
# exponential for the negative continues values

# make it fit better into range after log and exponential (sqrt? log again?)

# %%
# look for the ones over .5 or under -.5.. these are highly correlated ones
# flagging step

#every pair highly correlated need to be seperated into a different df

# make different dfs
    # 1 pair = 2
    # 2 pair = 4
    
# explain why theyre seperated

## do feature selection

# correlation is alwasy between -1 and 1

# merge all 3 parts together categorical back into .. categorical, contin (all the continues made.. not 1), target

# report all we did to change the data, not the data describing that we used to impute and change
# keep count of missing
